# %%
import os
import openai
from dotenv import load_dotenv

_ = load_dotenv(dotenv_path="../.env") # read local .env file
openai.api_key  = os.environ['OPENAI_API_KEY']
openai.api_type = "azure"
openai.api_base = os.environ['OPENAI_API_BASE']
openai.api_version = os.environ['OPENAI_API_VERSION']

import sys
sys.path.append('../')
from json_module import load_docs_from_jsonl, save_docs_to_jsonl

from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter, TextSplitter

# %% [markdown]
# ### KB splitting

# %%
kbs = load_docs_from_jsonl("kbs_without_jap2.jsonl")

# %%
kbs[0]
# Out:
# Document(page_content='Description\r\nThe IP address of the Solr server gets cached on the .NET level. This behavior might lead to connection issues if the solr.search connection string value is a domain name instead of a static IP address. If the DNS mapping for the domain is changed to a new IP address, the changes are not picked up by Sitecore instances until the instances have been restarted.This is a common scenario when using SearchStax Disaster Recovery. This article provides recommendations on how to reestablish connection to Solr when the DNS is updated to point to a new IP address.\r\nSolution\r\nTo reestablish connection to Solr when the DNS is updated to point to a new IP address, consider one of the following options:\r\nFor\xa0Sitecore XP 10.2.1 and later, enable the feature using the configuration file \\App_Config\\Include\\Examples\\Sitecore.ContentSearch.Solr.EnableConnectionLeaseTimeout.config.example.\r\nFor\xa0Sitecore XP 10.2.0, download and install the latest cumulative hotfix as specified in KB1001439.\r\nFor Sitecore XP 10.0.1, download and install the corresponding cumulative hotfix available in KB1001334.\r\nFor\xa0Sitecore XP 10.0.0, download and install the corresponding cumulative hotfix available in\xa0KB1001333.\r\nFor Sitecore XP 9.3 and earlier, you can follow the customization steps. The cached result of the IP address resolved for a domain name can be removed periodically so that you do not have to manually restart Sitecore instances when the DNS mapping changes. Note that the code sample is given only as a starting point.\r\nCreate the following class and build it into an assembly:\r\nusing System;\r\nusing System.Globalization;\r\nusing HttpWebAdapters;\r\nusing CommonServiceLocator;\r\nusing Microsoft.Extensions.DependencyInjection;\r\nusing Sitecore;\r\nusing Sitecore.ContentSearch.SolrProvider.Abstractions;\r\nnamespace YourNamespace\r\n{\r\n public class ResettableConnectionHttpWebRequestFactory : IHttpWebRequestFactory\r\n {\r\n private IHttpWebRequestFactory _httpWebRequestFactory;\r\n private readonly int _connectionLeaseTimeout;\r\n private static readonly TimeSpan DefaultConnectionLeaseTimeout = TimeSpan.FromMinutes(4);\r\n public ResettableConnectionHttpWebRequestFactory(string connectionLeaseTimeout)\r\n {\r\n _connectionLeaseTimeout = (int)DateUtil.ParseTimeSpan(connectionLeaseTimeout, DefaultConnectionLeaseTimeout, CultureInfo.CurrentCulture)\r\n .TotalMilliseconds;\r\n }\r\n public IHttpWebRequest Create(Uri url)\r\n {\r\n var request = GetHttpWebRequestFactory().Create(url);\r\n request.ServicePoint.ConnectionLeaseTimeout = _connectionLeaseTimeout;\r\n return request;\r\n }\r\n private IHttpWebRequestFactory GetHttpWebRequestFactory()\r\n {\r\n if (_httpWebRequestFactory != null)\r\n return _httpWebRequestFactory;\r\n return _httpWebRequestFactory = CreateHttpWebRequestFactory();\r\n }\r\n private IHttpWebRequestFactory CreateHttpWebRequestFactory()\r\n {\r\n IHttpWebRequestFactory resultFactory;\r\n var solrAddress = ServiceLocator.Current.GetService<BaseSolrSpecificSettings>().SolrAddress();\r\n if (solrAddress != null && solrAddress.UseBaseAuthentication)\r\n {\r\n resultFactory =\r\n new BasicAuthHttpWebRequestFactory(solrAddress.Username, solrAddress.Password);\r\n }\r\n else\r\n {\r\n resultFactory = new HttpWebRequestFactory();\r\n }\r\n return resultFactory;\r\n }\r\n }\r\n}\r\nNote: Add references to the following assemblies used by Sitecore:\r\nCommonServiceLocator\r\nMicrosoft.Extensions.DependencyInjection\r\nMicrosoft.Extensions.DependencyInjection.Abstractions\r\nSitecore.ContentSearch\r\nSitecore.ContentSearch.SolrProvider\r\nSitecore.Kernel\r\nSolrNet\r\nPut the assembly to the \\bin folder of the website.\r\nReference the class from the configuration by creating the configuration patch file in the \\App_Config\\Include\\zzz folder:\r\n<?xml version="1.0" encoding="utf-8"?>\r\n<configuration xmlns:patch="http://www.sitecore.net/xmlconfig/" xmlns:role="http:// ...

# %%
def split_kb():
    chunks = [[500,120], [300,90]]
    chunks_encoder = [200,150]

    for i in chunks:
        text_splitter = RecursiveCharacterTextSplitter(
            separators=[r"(\r\n).*(\r\n)", " ", ""],
            chunk_size = i[0],
            chunk_overlap  = i[1],
            length_function = len,
            is_separator_regex = True,
        )

        texts = text_splitter.split_documents(kbs)
        save_docs_to_jsonl(texts, "kb_recursive_split_chunk{chunksize}_chunkoverlap{chunkoverlap}.jsonl".format(chunksize=i[0], chunkoverlap=i[1]))

    for i in chunks_encoder:
        rec_text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
            chunk_size = i,
            chunk_overlap  = 0
        )

        rec_texts = rec_text_splitter.split_documents(kbs)
        save_docs_to_jsonl(rec_texts, "kb_recursive_split_chunk{chunksize}_tiktoken_encoder.jsonl".format(chunksize=i))
        

split_kb()

# %%
char_text_splitter = CharacterTextSplitter(
    separator="\r\n",
    chunk_size = 300,
    chunk_overlap  = 50,
    length_function = len,
    is_separator_regex= False,
)

char_texts = char_text_splitter.split_documents(kbs)
# Out:
# Created a chunk of size 412, which is longer than the specified 300
# Created a chunk of size 1087, which is longer than the specified 300
# Created a chunk of size 456, which is longer than the specified 300
# Created a chunk of size 1565, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 369, which is longer than the specified 300
# Created a chunk of size 707, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 307, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 839, which is longer than the specified 300
# Created a chunk of size 365, which is longer than the specified 300
# Created a chunk of size 463, which is longer than the specified 300
# Created a chunk of size 407, which is longer than the specified 300
# Created a chunk of size 409, which is longer than the specified 300
# Created a chunk of size 312, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 402, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 405, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 365, which is longer than the specified 300
# Created a chunk of size 335, which is longer than the specified 300
# Created a chunk of size 445, which is longer than the specified 300
# Created a chunk of size 401, which is longer than the specified 300
# Created a chunk of size 362, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 451, which is longer than the specified 300
# Created a chunk of size 529, which is longer than the specified 300
# Created a chunk of size 468, which is longer than the specified 300
# Created a chunk of size 326, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 421, which is longer than the specified 300
# Created a chunk of size 729, which is longer than the specified 300
# Created a chunk of size 369, which is longer than the specified 300
# Created a chunk of size 381, which is longer than the specified 300
# Created a chunk of size 359, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 307, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 587, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 603, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 456, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 406, which is longer than the specified 300
# Created a chunk of size 361, which is longer than the specified 300
# Created a chunk of size 351, which is longer than the specified 300
# Created a chunk of size 385, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 370, which is longer than the specified 300
# Created a chunk of size 398, which is longer than the specified 300
# Created a chunk of size 780, which is longer than the specified 300
# Created a chunk of size 352, which is longer than the specified 300
# Created a chunk of size 625, which is longer than the specified 300
# Created a chunk of size 416, which is longer than the specified 300
# Created a chunk of size 739, which is longer than the specified 300
# Created a chunk of size 337, which is longer than the specified 300
# Created a chunk of size 387, which is longer than the specified 300
# Created a chunk of size 395, which is longer than the specified 300
# Created a chunk of size 570, which is longer than the specified 300
# Created a chunk of size 361, which is longer than the specified 300
# Created a chunk of size 451, which is longer than the specified 300
# Created a chunk of size 959, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 407, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 378, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 349, which is longer than the specified 300
# Created a chunk of size 3163, which is longer than the specified 300
# Created a chunk of size 1289, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 450, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 343, which is longer than the specified 300
# Created a chunk of size 366, which is longer than the specified 300
# Created a chunk of size 455, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 580, which is longer than the specified 300
# Created a chunk of size 384, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 379, which is longer than the specified 300
# Created a chunk of size 372, which is longer than the specified 300
# Created a chunk of size 384, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 379, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 363, which is longer than the specified 300
# Created a chunk of size 348, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 596, which is longer than the specified 300
# Created a chunk of size 398, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 692, which is longer than the specified 300
# Created a chunk of size 608, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 539, which is longer than the specified 300
# Created a chunk of size 656, which is longer than the specified 300
# Created a chunk of size 1862, which is longer than the specified 300
# Created a chunk of size 467, which is longer than the specified 300
# Created a chunk of size 739, which is longer than the specified 300
# Created a chunk of size 416, which is longer than the specified 300
# Created a chunk of size 470, which is longer than the specified 300
# Created a chunk of size 715, which is longer than the specified 300
# Created a chunk of size 336, which is longer than the specified 300
# Created a chunk of size 659, which is longer than the specified 300
# Created a chunk of size 539, which is longer than the specified 300
# Created a chunk of size 657, which is longer than the specified 300
# Created a chunk of size 788, which is longer than the specified 300
# Created a chunk of size 655, which is longer than the specified 300
# Created a chunk of size 732, which is longer than the specified 300
# Created a chunk of size 715, which is longer than the specified 300
# Created a chunk of size 361, which is longer than the specified 300
# Created a chunk of size 654, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 436, which is longer than the specified 300
# Created a chunk of size 447, which is longer than the specified 300
# Created a chunk of size 344, which is longer than the specified 300
# Created a chunk of size 372, which is longer than the specified 300
# Created a chunk of size 402, which is longer than the specified 300
# Created a chunk of size 351, which is longer than the specified 300
# Created a chunk of size 510, which is longer than the specified 300
# Created a chunk of size 506, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 416, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 370, which is longer than the specified 300
# Created a chunk of size 695, which is longer than the specified 300
# Created a chunk of size 432, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 534, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 332, which is longer than the specified 300
# Created a chunk of size 404, which is longer than the specified 300
# Created a chunk of size 385, which is longer than the specified 300
# Created a chunk of size 353, which is longer than the specified 300
# Created a chunk of size 427, which is longer than the specified 300
# Created a chunk of size 1056, which is longer than the specified 300
# Created a chunk of size 636, which is longer than the specified 300
# Created a chunk of size 1277, which is longer than the specified 300
# Created a chunk of size 494, which is longer than the specified 300
# Created a chunk of size 603, which is longer than the specified 300
# Created a chunk of size 620, which is longer than the specified 300
# Created a chunk of size 732, which is longer than the specified 300
# Created a chunk of size 655, which is longer than the specified 300
# Created a chunk of size 331, which is longer than the specified 300
# Created a chunk of size 753, which is longer than the specified 300
# Created a chunk of size 780, which is longer than the specified 300
# Created a chunk of size 694, which is longer than the specified 300
# Created a chunk of size 587, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 3163, which is longer than the specified 300
# Created a chunk of size 373, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 526, which is longer than the specified 300
# Created a chunk of size 426, which is longer than the specified 300
# Created a chunk of size 496, which is longer than the specified 300
# Created a chunk of size 810, which is longer than the specified 300
# Created a chunk of size 339, which is longer than the specified 300
# Created a chunk of size 377, which is longer than the specified 300
# Created a chunk of size 397, which is longer than the specified 300
# Created a chunk of size 330, which is longer than the specified 300
# Created a chunk of size 392, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 579, which is longer than the specified 300
# Created a chunk of size 456, which is longer than the specified 300
# Created a chunk of size 329, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 343, which is longer than the specified 300
# Created a chunk of size 453, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 661, which is longer than the specified 300
# Created a chunk of size 606, which is longer than the specified 300
# Created a chunk of size 499, which is longer than the specified 300
# Created a chunk of size 375, which is longer than the specified 300
# Created a chunk of size 1292, which is longer than the specified 300
# Created a chunk of size 430, which is longer than the specified 300
# Created a chunk of size 491, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 345, which is longer than the specified 300
# Created a chunk of size 326, which is longer than the specified 300
# Created a chunk of size 409, which is longer than the specified 300
# Created a chunk of size 341, which is longer than the specified 300
# Created a chunk of size 448, which is longer than the specified 300
# Created a chunk of size 352, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 481, which is longer than the specified 300
# Created a chunk of size 382, which is longer than the specified 300
# Created a chunk of size 389, which is longer than the specified 300
# Created a chunk of size 446, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 383, which is longer than the specified 300
# Created a chunk of size 400, which is longer than the specified 300
# Created a chunk of size 357, which is longer than the specified 300
# Created a chunk of size 610, which is longer than the specified 300
# Created a chunk of size 527, which is longer than the specified 300
# Created a chunk of size 562, which is longer than the specified 300
# Created a chunk of size 375, which is longer than the specified 300
# Created a chunk of size 502, which is longer than the specified 300
# Created a chunk of size 551, which is longer than the specified 300
# Created a chunk of size 370, which is longer than the specified 300
# Created a chunk of size 441, which is longer than the specified 300
# Created a chunk of size 343, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 438, which is longer than the specified 300
# Created a chunk of size 1565, which is longer than the specified 300
# Created a chunk of size 458, which is longer than the specified 300
# Created a chunk of size 387, which is longer than the specified 300
# Created a chunk of size 311, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 445, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 446, which is longer than the specified 300
# Created a chunk of size 398, which is longer than the specified 300
# Created a chunk of size 737, which is longer than the specified 300
# Created a chunk of size 337, which is longer than the specified 300
# Created a chunk of size 336, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 612, which is longer than the specified 300
# Created a chunk of size 495, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 374, which is longer than the specified 300
# Created a chunk of size 364, which is longer than the specified 300
# Created a chunk of size 346, which is longer than the specified 300
# Created a chunk of size 348, which is longer than the specified 300
# Created a chunk of size 738, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 326, which is longer than the specified 300
# Created a chunk of size 510, which is longer than the specified 300
# Created a chunk of size 702, which is longer than the specified 300
# Created a chunk of size 434, which is longer than the specified 300
# Created a chunk of size 437, which is longer than the specified 300
# Created a chunk of size 533, which is longer than the specified 300
# Created a chunk of size 386, which is longer than the specified 300
# Created a chunk of size 353, which is longer than the specified 300
# Created a chunk of size 427, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 383, which is longer than the specified 300
# Created a chunk of size 450, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 311, which is longer than the specified 300
# Created a chunk of size 374, which is longer than the specified 300
# Created a chunk of size 402, which is longer than the specified 300
# Created a chunk of size 518, which is longer than the specified 300
# Created a chunk of size 359, which is longer than the specified 300
# Created a chunk of size 481, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 499, which is longer than the specified 300
# Created a chunk of size 352, which is longer than the specified 300
# Created a chunk of size 737, which is longer than the specified 300
# Created a chunk of size 458, which is longer than the specified 300
# Created a chunk of size 387, which is longer than the specified 300
# Created a chunk of size 311, which is longer than the specified 300
# Created a chunk of size 426, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 499, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 468, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 327, which is longer than the specified 300
# Created a chunk of size 302, which is longer than the specified 300
# Created a chunk of size 530, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 406, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 478, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 410, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 836, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 360, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 308, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 397, which is longer than the specified 300
# Created a chunk of size 555, which is longer than the specified 300
# Created a chunk of size 413, which is longer than the specified 300
# Created a chunk of size 467, which is longer than the specified 300
# Created a chunk of size 351, which is longer than the specified 300
# Created a chunk of size 506, which is longer than the specified 300
# Created a chunk of size 342, which is longer than the specified 300
# Created a chunk of size 819, which is longer than the specified 300
# Created a chunk of size 346, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 445, which is longer than the specified 300
# Created a chunk of size 555, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 1367, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 1367, which is longer than the specified 300
# Created a chunk of size 473, which is longer than the specified 300
# Created a chunk of size 614, which is longer than the specified 300
# Created a chunk of size 614, which is longer than the specified 300
# Created a chunk of size 597, which is longer than the specified 300
# Created a chunk of size 440, which is longer than the specified 300
# Created a chunk of size 392, which is longer than the specified 300
# Created a chunk of size 776, which is longer than the specified 300
# Created a chunk of size 776, which is longer than the specified 300
# Created a chunk of size 425, which is longer than the specified 300
# Created a chunk of size 359, which is longer than the specified 300
# Created a chunk of size 403, which is longer than the specified 300
# Created a chunk of size 376, which is longer than the specified 300
# Created a chunk of size 381, which is longer than the specified 300
# Created a chunk of size 425, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 450, which is longer than the specified 300
# Created a chunk of size 486, which is longer than the specified 300
# Created a chunk of size 413, which is longer than the specified 300
# Created a chunk of size 672, which is longer than the specified 300
# Created a chunk of size 680, which is longer than the specified 300
# Created a chunk of size 423, which is longer than the specified 300
# Created a chunk of size 520, which is longer than the specified 300
# Created a chunk of size 520, which is longer than the specified 300
# Created a chunk of size 548, which is longer than the specified 300
# Created a chunk of size 537, which is longer than the specified 300
# Created a chunk of size 453, which is longer than the specified 300
# Created a chunk of size 326, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 337, which is longer than the specified 300
# Created a chunk of size 342, which is longer than the specified 300
# Created a chunk of size 587, which is longer than the specified 300
# Created a chunk of size 389, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 492, which is longer than the specified 300
# Created a chunk of size 418, which is longer than the specified 300
# Created a chunk of size 366, which is longer than the specified 300
# Created a chunk of size 393, which is longer than the specified 300
# Created a chunk of size 434, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 536, which is longer than the specified 300
# Created a chunk of size 385, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 351, which is longer than the specified 300
# Created a chunk of size 392, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 532, which is longer than the specified 300
# Created a chunk of size 420, which is longer than the specified 300
# Created a chunk of size 387, which is longer than the specified 300
# Created a chunk of size 429, which is longer than the specified 300
# Created a chunk of size 746, which is longer than the specified 300
# Created a chunk of size 1030, which is longer than the specified 300
# Created a chunk of size 532, which is longer than the specified 300
# Created a chunk of size 485, which is longer than the specified 300
# Created a chunk of size 429, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 335, which is longer than the specified 300
# Created a chunk of size 521, which is longer than the specified 300
# Created a chunk of size 670, which is longer than the specified 300
# Created a chunk of size 482, which is longer than the specified 300
# Created a chunk of size 613, which is longer than the specified 300
# Created a chunk of size 347, which is longer than the specified 300
# Created a chunk of size 335, which is longer than the specified 300
# Created a chunk of size 521, which is longer than the specified 300
# Created a chunk of size 670, which is longer than the specified 300
# Created a chunk of size 429, which is longer than the specified 300
# Created a chunk of size 347, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 302, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 613, which is longer than the specified 300
# Created a chunk of size 568, which is longer than the specified 300
# Created a chunk of size 371, which is longer than the specified 300
# Created a chunk of size 515, which is longer than the specified 300
# Created a chunk of size 369, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 396, which is longer than the specified 300
# Created a chunk of size 395, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 421, which is longer than the specified 300
# Created a chunk of size 374, which is longer than the specified 300
# Created a chunk of size 715, which is longer than the specified 300
# Created a chunk of size 389, which is longer than the specified 300
# Created a chunk of size 343, which is longer than the specified 300
# Created a chunk of size 437, which is longer than the specified 300
# Created a chunk of size 327, which is longer than the specified 300
# Created a chunk of size 337, which is longer than the specified 300
# Created a chunk of size 1200, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 410, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 307, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 348, which is longer than the specified 300
# Created a chunk of size 454, which is longer than the specified 300
# Created a chunk of size 435, which is longer than the specified 300
# Created a chunk of size 587, which is longer than the specified 300
# Created a chunk of size 485, which is longer than the specified 300
# Created a chunk of size 1799, which is longer than the specified 300
# Created a chunk of size 835, which is longer than the specified 300
# Created a chunk of size 968, which is longer than the specified 300
# Created a chunk of size 435, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 2106, which is longer than the specified 300
# Created a chunk of size 862, which is longer than the specified 300
# Created a chunk of size 305, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 587, which is longer than the specified 300
# Created a chunk of size 485, which is longer than the specified 300
# Created a chunk of size 1799, which is longer than the specified 300
# Created a chunk of size 835, which is longer than the specified 300
# Created a chunk of size 968, which is longer than the specified 300
# Created a chunk of size 435, which is longer than the specified 300
# Created a chunk of size 380, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 492, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 1200, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 396, which is longer than the specified 300
# Created a chunk of size 330, which is longer than the specified 300
# Created a chunk of size 1005, which is longer than the specified 300
# Created a chunk of size 1243, which is longer than the specified 300
# Created a chunk of size 447, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 339, which is longer than the specified 300
# Created a chunk of size 1347, which is longer than the specified 300
# Created a chunk of size 1323, which is longer than the specified 300
# Created a chunk of size 2882, which is longer than the specified 300
# Created a chunk of size 521, which is longer than the specified 300
# Created a chunk of size 859, which is longer than the specified 300
# Created a chunk of size 457, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 590, which is longer than the specified 300
# Created a chunk of size 474, which is longer than the specified 300
# Created a chunk of size 335, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 329, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 590, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 474, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 559, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 2882, which is longer than the specified 300
# Created a chunk of size 659, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 1055, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 1040, which is longer than the specified 300
# Created a chunk of size 447, which is longer than the specified 300
# Created a chunk of size 381, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 2106, which is longer than the specified 300
# Created a chunk of size 368, which is longer than the specified 300
# Created a chunk of size 418, which is longer than the specified 300
# Created a chunk of size 347, which is longer than the specified 300
# Created a chunk of size 1045, which is longer than the specified 300
# Created a chunk of size 883, which is longer than the specified 300
# Created a chunk of size 542, which is longer than the specified 300
# Created a chunk of size 664, which is longer than the specified 300
# Created a chunk of size 308, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 377, which is longer than the specified 300
# Created a chunk of size 416, which is longer than the specified 300
# Created a chunk of size 332, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 10036, which is longer than the specified 300
# Created a chunk of size 857, which is longer than the specified 300
# Created a chunk of size 862, which is longer than the specified 300
# Created a chunk of size 375, which is longer than the specified 300
# Created a chunk of size 1055, which is longer than the specified 300
# Created a chunk of size 307, which is longer than the specified 300
# Created a chunk of size 1005, which is longer than the specified 300
# Created a chunk of size 1243, which is longer than the specified 300
# Created a chunk of size 447, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 339, which is longer than the specified 300
# Created a chunk of size 1040, which is longer than the specified 300
# Created a chunk of size 346, which is longer than the specified 300
# Created a chunk of size 1347, which is longer than the specified 300
# Created a chunk of size 469, which is longer than the specified 300
# Created a chunk of size 433, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 1208, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 857, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 396, which is longer than the specified 300
# Created a chunk of size 305, which is longer than the specified 300
# Created a chunk of size 980, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 344, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 341, which is longer than the specified 300
# Created a chunk of size 372, which is longer than the specified 300
# Created a chunk of size 305, which is longer than the specified 300
# Created a chunk of size 980, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 365, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 739, which is longer than the specified 300
# Created a chunk of size 2594, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 1094, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 1323, which is longer than the specified 300
# Created a chunk of size 360, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 436, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 449, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 1094, which is longer than the specified 300
# Created a chunk of size 396, which is longer than the specified 300
# Created a chunk of size 368, which is longer than the specified 300
# Created a chunk of size 542, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 883, which is longer than the specified 300
# Created a chunk of size 329, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 1449, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 437, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 307, which is longer than the specified 300
# Created a chunk of size 457, which is longer than the specified 300
# Created a chunk of size 562, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 521, which is longer than the specified 300
# Created a chunk of size 552, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 337, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 552, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 336, which is longer than the specified 300
# Created a chunk of size 316, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 739, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 2594, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 534, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 415, which is longer than the specified 300
# Created a chunk of size 376, which is longer than the specified 300
# Created a chunk of size 311, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 497, which is longer than the specified 300
# Created a chunk of size 302, which is longer than the specified 300
# Created a chunk of size 326, which is longer than the specified 300
# Created a chunk of size 384, which is longer than the specified 300
# Created a chunk of size 375, which is longer than the specified 300
# Created a chunk of size 595, which is longer than the specified 300
# Created a chunk of size 1045, which is longer than the specified 300
# Created a chunk of size 313, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 335, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 358, which is longer than the specified 300
# Created a chunk of size 372, which is longer than the specified 300
# Created a chunk of size 859, which is longer than the specified 300
# Created a chunk of size 390, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 354, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 1449, which is longer than the specified 300
# Created a chunk of size 354, which is longer than the specified 300
# Created a chunk of size 458, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 332, which is longer than the specified 300
# Created a chunk of size 483, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 1041, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 761, which is longer than the specified 300
# Created a chunk of size 658, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 1908, which is longer than the specified 300
# Created a chunk of size 353, which is longer than the specified 300
# Created a chunk of size 459, which is longer than the specified 300
# Created a chunk of size 901, which is longer than the specified 300
# Created a chunk of size 373, which is longer than the specified 300
# Created a chunk of size 368, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 586, which is longer than the specified 300
# Created a chunk of size 478, which is longer than the specified 300
# Created a chunk of size 3670, which is longer than the specified 300
# Created a chunk of size 331, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 1908, which is longer than the specified 300
# Created a chunk of size 336, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 3670, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 362, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 373, which is longer than the specified 300
# Created a chunk of size 413, which is longer than the specified 300
# Created a chunk of size 426, which is longer than the specified 300
# Created a chunk of size 451, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 418, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 1257, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 1199, which is longer than the specified 300
# Created a chunk of size 1264, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 371, which is longer than the specified 300
# Created a chunk of size 507, which is longer than the specified 300
# Created a chunk of size 1050, which is longer than the specified 300
# Created a chunk of size 631, which is longer than the specified 300
# Created a chunk of size 651, which is longer than the specified 300
# Created a chunk of size 689, which is longer than the specified 300
# Created a chunk of size 1295, which is longer than the specified 300
# Created a chunk of size 2120, which is longer than the specified 300
# Created a chunk of size 378, which is longer than the specified 300
# Created a chunk of size 3136, which is longer than the specified 300
# Created a chunk of size 419, which is longer than the specified 300
# Created a chunk of size 557, which is longer than the specified 300
# Created a chunk of size 497, which is longer than the specified 300
# Created a chunk of size 362, which is longer than the specified 300
# Created a chunk of size 301, which is longer than the specified 300
# Created a chunk of size 762, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 305, which is longer than the specified 300
# Created a chunk of size 462, which is longer than the specified 300
# Created a chunk of size 341, which is longer than the specified 300
# Created a chunk of size 444, which is longer than the specified 300
# Created a chunk of size 974, which is longer than the specified 300
# Created a chunk of size 1354, which is longer than the specified 300
# Created a chunk of size 759, which is longer than the specified 300
# Created a chunk of size 974, which is longer than the specified 300
# Created a chunk of size 307, which is longer than the specified 300
# Created a chunk of size 993, which is longer than the specified 300
# Created a chunk of size 546, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 371, which is longer than the specified 300
# Created a chunk of size 465, which is longer than the specified 300
# Created a chunk of size 459, which is longer than the specified 300
# Created a chunk of size 546, which is longer than the specified 300
# Created a chunk of size 562, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 344, which is longer than the specified 300
# Created a chunk of size 562, which is longer than the specified 300
# Created a chunk of size 364, which is longer than the specified 300
# Created a chunk of size 546, which is longer than the specified 300
# ...
# Created a chunk of size 1411, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 364, which is longer than the specified 300
# Created a chunk of size 477, which is longer than the specified 300
# Created a chunk of size 333, which is longer than the specified 300
# Created a chunk of size 332, which is longer than the specified 300
# Created a chunk of size 422, which is longer than the specified 300
# Created a chunk of size 308, which is longer than the specified 300
# Created a chunk of size 338, which is longer than the specified 300
# Created a chunk of size 515, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 635, which is longer than the specified 300
# Created a chunk of size 774, which is longer than the specified 300
# Created a chunk of size 430, which is longer than the specified 300
# Created a chunk of size 1927, which is longer than the specified 300
# Created a chunk of size 431, which is longer than the specified 300
# Created a chunk of size 366, which is longer than the specified 300
# Created a chunk of size 496, which is longer than the specified 300
# Created a chunk of size 415, which is longer than the specified 300
# Created a chunk of size 487, which is longer than the specified 300
# Created a chunk of size 500, which is longer than the specified 300
# Created a chunk of size 541, which is longer than the specified 300
# Created a chunk of size 2068, which is longer than the specified 300
# Created a chunk of size 1345, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 1411, which is longer than the specified 300
# Created a chunk of size 1213, which is longer than the specified 300
# Created a chunk of size 574, which is longer than the specified 300
# Created a chunk of size 644, which is longer than the specified 300
# Created a chunk of size 691, which is longer than the specified 300
# Created a chunk of size 442, which is longer than the specified 300
# Created a chunk of size 757, which is longer than the specified 300
# Created a chunk of size 339, which is longer than the specified 300
# Created a chunk of size 821, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 633, which is longer than the specified 300
# Created a chunk of size 414, which is longer than the specified 300
# Created a chunk of size 440, which is longer than the specified 300
# Created a chunk of size 450, which is longer than the specified 300
# Created a chunk of size 371, which is longer than the specified 300
# Created a chunk of size 305, which is longer than the specified 300
# Created a chunk of size 385, which is longer than the specified 300
# Created a chunk of size 343, which is longer than the specified 300
# Created a chunk of size 327, which is longer than the specified 300
# Created a chunk of size 344, which is longer than the specified 300
# Created a chunk of size 413, which is longer than the specified 300
# Created a chunk of size 339, which is longer than the specified 300
# Created a chunk of size 628, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 370, which is longer than the specified 300
# Created a chunk of size 810, which is longer than the specified 300
# Created a chunk of size 939, which is longer than the specified 300
# Created a chunk of size 508, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 526, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 729, which is longer than the specified 300
# Created a chunk of size 441, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 345, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 342, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 471, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 628, which is longer than the specified 300
# Created a chunk of size 393, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 314, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 2508, which is longer than the specified 300
# Created a chunk of size 1207, which is longer than the specified 300
# Created a chunk of size 1404, which is longer than the specified 300
# Created a chunk of size 1601, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 304, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 489, which is longer than the specified 300
# Created a chunk of size 304, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 898, which is longer than the specified 300
# Created a chunk of size 419, which is longer than the specified 300
# Created a chunk of size 846, which is longer than the specified 300
# Created a chunk of size 566, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 422, which is longer than the specified 300
# Created a chunk of size 484, which is longer than the specified 300
# Created a chunk of size 2508, which is longer than the specified 300
# Created a chunk of size 1207, which is longer than the specified 300
# Created a chunk of size 1404, which is longer than the specified 300
# Created a chunk of size 1601, which is longer than the specified 300
# Created a chunk of size 365, which is longer than the specified 300
# Created a chunk of size 487, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 680, which is longer than the specified 300
# Created a chunk of size 528, which is longer than the specified 300
# Created a chunk of size 432, which is longer than the specified 300
# Created a chunk of size 378, which is longer than the specified 300
# Created a chunk of size 376, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 606, which is longer than the specified 300
# Created a chunk of size 352, which is longer than the specified 300
# Created a chunk of size 351, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 667, which is longer than the specified 300
# Created a chunk of size 374, which is longer than the specified 300
# Created a chunk of size 606, which is longer than the specified 300
# Created a chunk of size 351, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 558, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 369, which is longer than the specified 300
# Created a chunk of size 497, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 409, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 416, which is longer than the specified 300
# Created a chunk of size 595, which is longer than the specified 300
# Created a chunk of size 356, which is longer than the specified 300
# Created a chunk of size 354, which is longer than the specified 300
# Created a chunk of size 335, which is longer than the specified 300
# Created a chunk of size 667, which is longer than the specified 300
# Created a chunk of size 340, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 680, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 302, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 554, which is longer than the specified 300
# Created a chunk of size 327, which is longer than the specified 300
# Created a chunk of size 441, which is longer than the specified 300
# Created a chunk of size 458, which is longer than the specified 300
# Created a chunk of size 2007, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 318, which is longer than the specified 300
# Created a chunk of size 1187, which is longer than the specified 300
# Created a chunk of size 1081, which is longer than the specified 300
# Created a chunk of size 339, which is longer than the specified 300
# Created a chunk of size 510, which is longer than the specified 300
# Created a chunk of size 462, which is longer than the specified 300
# Created a chunk of size 636, which is longer than the specified 300
# Created a chunk of size 667, which is longer than the specified 300
# Created a chunk of size 780, which is longer than the specified 300
# Created a chunk of size 1353, which is longer than the specified 300
# Created a chunk of size 377, which is longer than the specified 300
# Created a chunk of size 582, which is longer than the specified 300
# Created a chunk of size 484, which is longer than the specified 300
# Created a chunk of size 355, which is longer than the specified 300
# Created a chunk of size 409, which is longer than the specified 300
# Created a chunk of size 512, which is longer than the specified 300
# Created a chunk of size 2007, which is longer than the specified 300
# Created a chunk of size 410, which is longer than the specified 300
# Created a chunk of size 323, which is longer than the specified 300
# Created a chunk of size 1187, which is longer than the specified 300
# Created a chunk of size 1081, which is longer than the specified 300
# Created a chunk of size 362, which is longer than the specified 300
# Created a chunk of size 320, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 334, which is longer than the specified 300
# Created a chunk of size 345, which is longer than the specified 300
# Created a chunk of size 324, which is longer than the specified 300
# Created a chunk of size 605, which is longer than the specified 300
# Created a chunk of size 510, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 308, which is longer than the specified 300
# Created a chunk of size 1099, which is longer than the specified 300
# Created a chunk of size 312, which is longer than the specified 300
# Created a chunk of size 526, which is longer than the specified 300
# Created a chunk of size 400, which is longer than the specified 300
# Created a chunk of size 325, which is longer than the specified 300
# Created a chunk of size 373, which is longer than the specified 300
# Created a chunk of size 368, which is longer than the specified 300
# Created a chunk of size 365, which is longer than the specified 300
# Created a chunk of size 546, which is longer than the specified 300
# Created a chunk of size 593, which is longer than the specified 300
# Created a chunk of size 309, which is longer than the specified 300
# Created a chunk of size 322, which is longer than the specified 300
# Created a chunk of size 347, which is longer than the specified 300
# Created a chunk of size 419, which is longer than the specified 300
# Created a chunk of size 497, which is longer than the specified 300
# Created a chunk of size 326, which is longer than the specified 300
# Created a chunk of size 382, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 558, which is longer than the specified 300
# Created a chunk of size 310, which is longer than the specified 300
# Created a chunk of size 399, which is longer than the specified 300
# Created a chunk of size 558, which is longer than the specified 300
# Created a chunk of size 321, which is longer than the specified 300
# Created a chunk of size 345, which is longer than the specified 300
# Created a chunk of size 605, which is longer than the specified 300
# Created a chunk of size 413, which is longer than the specified 300
# Created a chunk of size 761, which is longer than the specified 300
# Created a chunk of size 658, which is longer than the specified 300
# Created a chunk of size 352, which is longer than the specified 300
# Created a chunk of size 315, which is longer than the specified 300
# Created a chunk of size 522, which is longer than the specified 300
# Created a chunk of size 402, which is longer than the specified 300
# Created a chunk of size 352, which is longer than the specified 300
# Created a chunk of size 631, which is longer than the specified 300
# Created a chunk of size 416, which is longer than the specified 300
# Created a chunk of size 354, which is longer than the specified 300
# Created a chunk of size 381, which is longer than the specified 300
# Created a chunk of size 337, which is longer than the specified 300
# Created a chunk of size 306, which is longer than the specified 300
# Created a chunk of size 317, which is longer than the specified 300
# Created a chunk of size 430, which is longer than the specified 300
# Created a chunk of size 402, which is longer than the specified 300
# Created a chunk of size 699, which is longer than the specified 300
# Created a chunk of size 505, which is longer than the specified 300
# Created a chunk of size 370, which is longer than the specified 300
# Created a chunk of size 357, which is longer than the specified 300
# Created a chunk of size 303, which is longer than the specified 300
# Created a chunk of size 319, which is longer than the specified 300
# Created a chunk of size 662, which is longer than the specified 300
# Created a chunk of size 478, which is longer than the specified 300
# Created a chunk of size 347, which is longer than the specified 300
# Created a chunk of size 402, which is longer than the specified 300
# Created a chunk of size 689, which is longer than the specified 300
# Created a chunk of size 510, which is longer than the specified 300
# Created a chunk of size 373, which is longer than the specified 300

# %%
char_texts[0:10]
# Out:
# [Document(page_content='Systems infrastructure', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='Sitecore Discover\xa0is designed to automatically scale capacity as the traffic demand increases. However, Sitecore Discover also preemptively ramps up the capacity of all services during this time of the year which includes Thanksgiving, Black Friday, Cyber Monday, Christmas, and New Year.', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content="During Sitecore Discover's load testing, the system was able to easily handle\xa05x the daily peak traffic. Based on this experience, the Sitecore Discover engineering and operations teams are confident that the system can comfortably handle the anticipated holiday load.\r\nPersonnel and processes", metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='Personnel and processes\r\nIn addition to the above, Sitecore Discover will also have additional personnel on duty to monitor and assist with any issues that are reported during the peak holiday traffic. Below is a summary of the holiday support plan in place.\r\nSupport structure\r\nOn-call Support', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='Support structure\r\nOn-call Support\r\nTechnical Support Solution Engineers are on call 24/7\r\nHow to contact Support\r\n\xa0As the primary contact method,\xa0open a case through Sitecore Support Portal.\xa0 For more details, see\xa0KB0654910.', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='Alternatively, it is possible to send an email to ReflektionSupport@sitecore.com. This email automatically creates a support ticket and triggers a response from the Sitecore support team.\xa0\r\nEscalation Method', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='Escalation Method\r\n\xa0Sitecore Discover has established escalation processes through PagerDuty with the\xa0 connected phone numbers for internal Sitecore personnel.\r\nService Degradation Information', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='If there is any service degradation, Sitecore Discover provides updates at https://support.sitecore.com/status and https://status.reflektion.com/. On these pages, customers can subscribe to the Discover System Status notification service to receive updates in real-time.', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003178', 'lastmod': '2023-10-17', 'title': 'Support Information - Sitecore Discover - 2023 Holiday Preparedness'}),
#  Document(page_content='概要\r\nこの記事では、Sitecore Managed Cloud – PaaS 2.0環境で、Azure App Serviceのデプロイ スロットを有効化する方法について解説します。\r\nデプロイ スロットの説明', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003176', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003176', 'lastmod': '2023-10-17', 'title': 'Support Information - Managed Cloud Standard  – Web Appのデプロイ スロット（PaaS 2.0）'}),
#  Document(page_content='デプロイ スロットの説明\r\nAzure App ServiceにWeb Appをデプロイする際に、Standard、Premium、またはIsolated価格レベルで実行する場合、デフォルトの本番スロットのかわりに独立したデプロイ スロットを使用することができます。デプロイ スロットはホスト名を持ったライブAppです。Appの内容および構成要素は二つのデプロイ スロット（本番スロットを含む）の間でスワップすることができます。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003176', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1003176', 'lastmod': '2023-10-17', 'title': 'Support Information - Managed Cloud Standard  – Web Appのデプロイ スロット（PaaS 2.0）'})]

# %%
rec_text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 300,
    chunk_overlap  = 0
)

rec_texts = rec_text_splitter.split_documents(kbs)

# %%
rec_texts[5000:5020]
# Out:
# [Document(page_content='XPでは、データがフラッシュされていなくても、設定されたlog4netアペンダーごとに新しいログ ファイルが作成されるため、この挙動は仕様通りのものです。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002591', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002591', 'lastmod': '2022-10-22', 'title': 'Known Issues - クリーンなSitecoreインスタンスを使用する際に、contactMergeDataUpgrade.logファイルが作成される'}),
#  Document(page_content='このような挙動は無視しても問題はありませんが、空のログ ファイルを作成されないようにしたい場合、下記の解決策を参照してください。\r\n解決策\r\ncontactMergeDataUpgrade.logを生成しないようにするには、\\App_Config\\Sitecore\\Marketing.xDB\\Sitecore.Xdb.Processing.ContactMerge.configファイルを無効化（ファイル名を変更）してください。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002591', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002591', 'lastmod': '2022-10-22', 'title': 'Known Issues - クリーンなSitecoreインスタンスを使用する際に、contactMergeDataUpgrade.logファイルが作成される'}),
#  Document(page_content='説明\r\n異なるCRM組織（または異なるCRMインスタンス）への複数の接続を設定する際、CRMセキュリティ プロバイダにマップされたすべてのドメインには、最初に初期化されたCRM接続のユーザーおよびルールが含まれます。それ以外のすべてのCRM接続は無視されます。\r\n本件はDynamics CRM Campaign Integrationモジュールのすべてのバージョンに該当します。\r\n解決策\r\nCRM Security Provider 2.0およびその以降のバージョンを実行する場合、下位のパッチを適用してください：', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002561', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002561', 'lastmod': '2022-10-22', 'title': 'Known Issues - CRM Security Providerが複数の接続をサポートしない'}),
#  Document(page_content='Sitecore.Support.422079.dllアセンブリを/binフォルダーにコピーします。\r\nweb.configファイル配下のすべてのCRM Security Providerの定義のタイプを変更してください：\r\n<add name="crm" type="CRMSecurityProvider.Support.CRMMembershipProvider, Sitecore.Support.422079" .../>\r\n<add name="crm" type="CRMSecurityProvider.Support.CRMRoleProvider, Sitecore.Support.422079" .../>\r\n<add name="crm" type="CRMSecurityProvider.Support.CRMProfileProvider, Sitecore.Support.422079" .../>\r\nそれ以前のバージョンの場合、製品のバージョンをCRM Security Provider 2.0以降のバージョンにアップデートし、上記のパッチを適用してください。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002561', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002561', 'lastmod': '2022-10-22', 'title': 'Known Issues - CRM Security Providerが複数の接続をサポートしない'}),
#  Document(page_content='説明\r\nSitecoreコントロール パネルにおけるレポートの[Refresh Aggregated Data]オプションを使用する際に、次のエラーが発生する場合があります。\r\nSystem.ExceptionMessage: Cannot find the object "Cache_TrafficByDay" because it does not exist or you do not have permissions.Source: Sitecore.Kernelat Sitecore.Data.DataProviders.Sql.DataProviderCommand.ExecuteNonQuery()at Sitecore.Data.DataProviders.Sql.SqlDataApi.Execute(Stringsql, Object[] parameters)at Sitecore.Analytics.Data.DataAccess.DataAdapters.Sql.SqlMaintenance.UpdateReportsSummary()at Sitecore.Shell.Applications.Analytics.Reports.Summary.UpdateForm.UpdateReportsRunner.Run()Nested Exception\r\nException: System.Data.DataExceptionMessage: Error executing SQL command: execsp_sc_refresh_views', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002595', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002595', 'lastmod': '2022-10-22', 'title': 'Known Issues - レポートの「Refresh Aggregated Data」オプションが、最小限のSQL権限で実行できない'}),
#  Document(page_content='上記のエラーは、対応するストアド プロシージャを実行するために必要なアクセス許可がSQLアカウントにない場合に発生します。例えば、「db_datareader」および 「db_datawriter」アクセス許可のみを持つアカウントを使用してSQL Server Analyticsデータベースに接続するようにシステムが構成されている場合などです。\r\n解決策\r\n解決策 1:\r\n「db_owner」ロールをSQLユーザー アカウントに割り当てます。\r\n解決策 2:\r\nSQLユーザー アカウントに「Execute」権限と「Alter any Schema」権限を割り当てます。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002595', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002595', 'lastmod': '2022-10-22', 'title': 'Known Issues - レポートの「Refresh Aggregated Data」オプションが、最小限のSQL権限で実行できない'}),
#  Document(page_content='説明\r\n「Master」データベースで構成されていない場合に、Sitecore Analyticsが有効になっているSitecore インスタンスのSitecore ログ ファイルで、次のエラーが記録される場合があります。\r\n以下のエラーは、Sitecoreが「Sitecore.Analytics.Tasks.EmailReportsTask」スケジュール タスクを実行する際に発生し、通常の構成ではCD環境で発生します。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002598', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002598', 'lastmod': '2022-10-22', 'title': 'Known Issues - 「Master」データベースがない場合にEmailReportsTask が失敗する'}),
#  Document(page_content='ERROR ExceptionException: System.Reflection.TargetInvocationExceptionMessage: Exception has been thrown by the target of an invocation.Source: mscorlib\xa0 \xa0at System.RuntimeMethodHandle._InvokeMethodFast(IRuntimeMethodInfo method, Object target, Object[] arguments, SignatureStruct& sig, MethodAttributes methodAttributes, RuntimeType typeOwner)\xa0 \xa0at System.RuntimeMethodHandle.InvokeMethodFast(IRuntimeMethodInfo method, Object target, Object[] arguments, Signature sig, MethodAttributes methodAttributes, RuntimeType typeOwner)\xa0 \xa0at System.Reflection.RuntimeMethodInfo.Invoke(Object obj, BindingFlags invokeAttr, Binder binder, Object[] parameters, CultureInfo culture, Boolean skipVisibilityChecks)\xa0 \xa0at System.Reflection.RuntimeMethodInfo.Invoke(Object obj, BindingFlags invokeAttr, Binder binder, Object[] parameters, CultureInfo culture)\xa0 \xa0at System.Reflection.MethodBase.Invoke(Object obj, Object[] parameters)\xa0 \xa0at (Object , Object[] )\xa0 \xa0at Sitecore.Pipelines.CorePipeline.Run(PipelineArgs args)\xa0 \xa0at Sitecore.Jobs.Job.ThreadEntry(Object state)\r\nNested Exception', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002598', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002598', 'lastmod': '2022-10-22', 'title': 'Known Issues - 「Master」データベースがない場合にEmailReportsTask が失敗する'}),
#  Document(page_content="Exception: System.InvalidOperationExceptionMessage: Could not find configuration node: databases/database[@id='master']Source: Sitecore.Kernel\xa0 \xa0at Sitecore.Diagnostics.Assert.IsTrue(Boolean condition, String message)\xa0 \xa0at Sitecore.Configuration.Factory.GetConfigNode(String xpath, Boolean assert)\xa0 \xa0at Sitecore.Configuration.Factory.CreateObject(String configPath, String[] parameters, Boolean assert)\xa0 \xa0at Sitecore.Configuration.Factory.GetDatabase(String name)\xa0 \xa0at Sitecore.Analytics.Tasks.EmailReportsTask.GetLastRun()\xa0 \xa0at Sitecore.Analytics.Tasks.EmailReportsTask.IsDue()\xa0 \xa0at Sitecore.Analytics.Tasks.EmailReportsTask.Run()\r\n解決策\r\n「Scaling Guide」ドキュメントの「Configuring Scheduling」節の手順を適用して、タスクを無効にするか、別のデータベースを使用するように構成してください。", metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002598', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002598', 'lastmod': '2022-10-22', 'title': 'Known Issues - 「Master」データベースがない場合にEmailReportsTask が失敗する'}),
#  Document(page_content='説明\r\n無効なMaxMindトークンでAnalyticsを実行すると、しばらくして一部のIPルックアップが「INVALID_LICENSE_KEY」、「LICENSE_EXPIRED」、「OUT_OF_QUERIES」等のメッセージで失敗する場合があります。\r\nMaxMind設定を有効なトークンで更新し、[Update blank entries]モードを使用して[コントロール パネル]にて[Refresh Lookups]ウィザードを手動で実行した後でも、上記のようなメッセージが正しい情報で更新されずにAnalyticsレポートに記録される場合があります。\r\n解決策', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'lastmod': '2022-10-21', 'title': 'Known Issues - MaxMindルックアップが更新されない'}),
#  Document(page_content='本事象を解決するには、以下の 2 つの解決策のいずれかを適用してください。\r\n[コントロール パネル] -> [Analytics]メニューから[Refresh Lookups]ダイアログを実行し、[Update all entries]モードを選択します。\r\n註：「Analytics」データベースに正しく解決された多数のIPアドレスがすでに含まれている場合、本解決策を実施するとMaxMindサービスへの過剰な呼び出しが発生する可能性があることに注意してください。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'lastmod': '2022-10-21', 'title': 'Known Issues - MaxMindルックアップが更新されない'}),
#  Document(page_content='「Analytics」データベースで次のクエリを実行してから、[コントロール パネル] -> [Analytics]メニューから[Refresh Lookups]ダイアログを実行し、[Update blank entries]モードを選択します。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'lastmod': '2022-10-21', 'title': 'Known Issues - MaxMindルックアップが更新されない'}),
#  Document(page_content="DECLARE @empty_location UNIQUEIDENTIFIER; SET @empty_location = (SELECT TOP 1 [LocationId] FROM [Locations] WHERE [BusinessName] = '' AND [Country] = '');UPDATE [GeoIps] SET [CachedValue] = '', [Fetched] = 0, [Status] = 0 WHERE [CachedValue] LIKE '%<businessname>INVALID_LICENSE_KEY</businessname>%' OR [CachedValue] LIKE '%<businessname>LICENSE_EXPIRED</businessname>%' OR [CachedValue] LIKE '%<businessname>OUT_OF_QUERIES</businessname>%' GOUPDATE [Visits] SET \xa0[LocationId] = @empty_location, [BusinessName] = '', [City] = '' WHERE [BusinessName] = 'INVALID_LICENSE_KEY' OR [BusinessName] = 'LICENSE_EXPIRED' OR [BusinessName] = 'OUT_OF_QUERIES' GO", metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002584', 'lastmod': '2022-10-21', 'title': 'Known Issues - MaxMindルックアップが更新されない'}),
#  Document(page_content='説明\r\nxConnectでMongoDB Atlasを動作させるには、2つの方法が挙げられます。\r\n解決策\r\n（「+srv」を含まない） 古い形式の接続文字列を使用します。例：\r\nmongodb://sa:12345@cluster0-shard-00-00-test.mongodb.net:27017,cluster0-shard-00-01-test.mongodb.net:27017,cluster0-shard-00-02-test.mongodb.net:27017/test?ssl=true&amp;replicaSet=Cluster0-shard-0&amp;authSource=admin&amp;retryWrites=true&amp;w=majority\r\nSRV文字列の場合、xConnectのWeb.configファイルの<assemblybinding>セクション配下にバインディング リダイレクトを追加します。\r\n<dependentAssembly>', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002558', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002558', 'lastmod': '2022-10-21', 'title': "How-to's - xConnectでMongoDB Atlasを動作させるための方法"}),
#  Document(page_content='<assemblyIdentity name="System.Buffers" publicKeyToken="cc7b13ffcd2ddd51" culture="neutral"/>\r\n  <bindingRedirect oldVersion="0.0.0.0-4.0.2.0" newVersion="4.0.3.0"/>\r\n</dependentAssembly>\r\n註：上記のどちらの方法でも、xConnect文字列のパラメータを区切る際には、「&」の代わりに「&amp;」を使用する必要があります。以下の例を参照してください。\r\n誤った例：\r\nmongodb+srv://sa:12345@cluster0-test.mongodb.net/test?retryWrites=true&w=majority\r\n正しい例：\r\nmongodb+srv://sa:12345@cluster0-test.mongodb.net/test?retryWrites=true&amp;w=majority', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002558', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002558', 'lastmod': '2022-10-21', 'title': "How-to's - xConnectでMongoDB Atlasを動作させるための方法"}),
#  Document(page_content='説明\r\nSitecore サイトで Sitecore MVC プレゼンテーションを使用する際に、多変量テストで次の問題が発生する可能性があります。\r\n多変量テストがセットアップされ、公開・実行されている場合、サイトの訪問者に、テスト バリエーションの 1 つではなく、プレゼンテーション データ ソース アイテムのコンテンツが表示される場合があります。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002575', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002575', 'lastmod': '2022-10-21', 'title': 'Known Issues - Sitecore MVC プレゼンテーション使用時の多変量テストの問題'}),
#  Document(page_content='[コンポーネントのテスト] ダイアログ ボックスで最初のバリエーションの [テスト コンテンツ アイテム] フィールドの値を変更する際に、[保存] ボタンをクリックすると、最初のバリエーションではなくプレゼンテーション データ ソース アイテムのコンテンツがページ エディターに表示される場合があります。\r\n解決策\r\n上記の問題を修正するには、Sitecore のバージョンに応じて次のパッチをダウンロードしてインストールしてください。\r\nSitecore バージョン 7.2 ～ 7.5 rev. 150130 (7.5 Update-1) 向け：\xa0Sitecore.Support.412646.zip', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002575', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002575', 'lastmod': '2022-10-21', 'title': 'Known Issues - Sitecore MVC プレゼンテーション使用時の多変量テストの問題'}),
#  Document(page_content='Sitecore バージョン 7.5 rev. 150212 (7.5 Update-2) 向け：\xa0Sitecore.Support.412646 (7.5 rev. 150212).zip\r\n\xa0\r\n上記のパッチは通常の Sitecore パッケージです。 Sitecore インストール ウィザードを使用してパッケージをインストールしてください。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002575', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002575', 'lastmod': '2022-10-21', 'title': 'Known Issues - Sitecore MVC プレゼンテーション使用時の多変量テストの問題'}),
#  Document(page_content='説明\r\n「web.config」ファイルの「exmEnabled:define」が「no」に設定されている場合、マーケティング定義の展開後にエラーが発生することがあります。次のメッセージがログ ファイルに記録されます。', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002580', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002580', 'lastmod': '2022-10-21', 'title': 'Known Issues - EXMを無効にすると、ログ ファイルに「System.InvalidOperationException」エラーが記録される'}),
#  Document(page_content='304 16:54:29 ERROR Aggregation ErrorException: System.InvalidOperationExceptionMessage: Dimension could not be resolved for for dimension id: b459a0ca-9f43-4ac1-8e6d-549e2a3de674Source: Sitecore.ExperienceAnalytics.Aggregation\xa0 \xa0at Sitecore.ExperienceAnalytics.Aggregation.Pipeline.SegmentProcessor.ProcessSegments(IInteractionAggregationContext context, IEnumerable`1 segments)\xa0 \xa0at Sitecore.ExperienceAnalytics.Aggregation.Pipeline.InteractionProcessor.AggregateSegments(IInteractionAggregationContext context, AggregationScope scope)\xa0 \xa0at Sitecore.Analytics.Aggregation.Pipeline.InteractionAggregationPipelineProcessor.Process(InteractionAggregationPipelineArgs args)Nested Exception...\r\n解決策', metadata={'source': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002580', 'loc': 'https://support.sitecore.com/kb?id=kb_article_view&sysparm_article=KB1002580', 'lastmod': '2022-10-21', 'title': 'Known Issues - EXMを無効にすると、ログ ファイルに「System.InvalidOperationException」エラーが記録される'})]

# %%
save_docs_to_jsonl(rec_texts, "recursive_split_chunk300_tiktoken_encoder.jsonl")

# %% [markdown]
# ### Docs splitting

# %%
docs = load_docs_from_jsonl("docsites_without_jap2.jsonl")

# %%
def split_docs():
    chunks = [[500,120], [200, 50]]
    chunks_encoder = [300,100]

    for i in chunks:
        text_splitter = RecursiveCharacterTextSplitter(
            separators=[r"(\n).*(\n)", " ", ""],
            chunk_size = i[0],
            chunk_overlap  = i[1],
            length_function = len,
            is_separator_regex = True,
        )

        texts = text_splitter.split_documents(docs)
        save_docs_to_jsonl(texts, "docs_recursive_split_chunk{chunksize}_chunkoverlap{chunkoverlap}.jsonl".format(chunksize=i[0], chunkoverlap=i[1]))

    for i in chunks_encoder:
        rec_text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
            chunk_size = i,
            chunk_overlap  = 0
        )

        rec_texts = rec_text_splitter.split_documents(docs)
        save_docs_to_jsonl(rec_texts, "docs_recursive_split_chunk{chunksize}_tiktoken_encoder.jsonl".format(chunksize=i))
        

split_docs()

# %%
text_splitter = RecursiveCharacterTextSplitter(
            separators=[r"(\n).*(\n)", " ", ""],
            chunk_size = 300,
            chunk_overlap  = 70,
            length_function = len,
            is_separator_regex = True,
)

# %%
texts = text_splitter.split_documents(docs)

# %%
texts[0:20]
# Out:
# [Document(page_content='View all the Sitecore Cloud offerings to best target campaigns, scale your solution, and develop a disaster recovery plan that is custom-made for your organization and requirements.', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='This overview, and the following Sitecore Cloud Services overview diagram, takes you through all the Sitecore Cloud offerings, what their functionality is, what you can use them for, and how the different modules integrate with each other and the Sitecore Experience Platform (XP).\n\n\nNote', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Note\nThis topic describes how to deploy Sitecore on Microsoft Azure with Azure App Services (PaaS). If you are deploying with Docker Containers with Kubernetes, please refer to this Managed Cloud documentation version instead.', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Refer to the Module versions section to understand how all of the different Cloud modules relate to the various versions of the Sitecore platform, and use the Sitecore Cloud Status page to check how the various Cloud services are operating.\nModule versions', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Module versions\n\n\nSome of the Sitecore Cloud modules use a different versioning system to the Sitecore platform. Refer to the Sitecore compatibility guide to learn about:\nAll of the Sitecore compatibility tables.\n\n\nThe xDB and Managed Cloud compatibility tables.\nThe Azure compatibility tables.', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='The Azure compatibility tables.\n\n\nMany compatibility articles for the different Sitecore topologies and tiers.\nRefer to the following table to avoid confusion and understand which offerings are available for the Sitecore solution that you are currently running:\n\n\nSitecore Cloud module/service', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Sitecore Cloud module/service\nCompatible with Sitecore platform version\n\n\nAzure Monitoring and Alerts\n10.1, 10.0, 9.3, 9.2, 9.1\n\n\nAzure Search and indexing\n9.3, 9.2, 9.1, 9.0, 8.2\n\n\nAzure Session State\n10.1, 10.0, 9.3, 9.2, 9.1, 9.0, 8.2\n\n\nAzure Web Application Firewall (WAF)', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Azure Web Application Firewall (WAF)\n10.1, 10.0, 9.3, 9.2, 9.1\n\n\nApp Service Environment (ASE)\n9.3, 9.2, 9.1\n\n\nBlob Storage\n10.1, 10.0, 9.3\n\n\nContent Delivery Network (CDN)\n10.1, 10.0, 9.3, 9.2, 9.1\n\n\nSitecore Azure\n8.1, 8.0\n\n\nSitecore Azure Toolkit (version 2.6)\n10.1', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Sitecore Azure\n8.1, 8.0\n\n\nSitecore Azure Toolkit (version 2.6)\n10.1\n\n\nSitecore Azure Toolkit (version 2.5)\n10.0\n\n\nSitecore Azure Toolkit (version 2.4)\n9.3\n\n\nSitecore Azure Toolkit (version 2.3)\n9.2\n\n\nSitecore Azure Toolkit (version 2.2)\n9.1\n\n\nSitecore Azure Toolkit (version 2.1)\n9.1, 9.0, 8.2', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='9.1\n\n\nSitecore Azure Toolkit (version 2.1)\n9.1, 9.0, 8.2\n\n\nSitecore Azure Toolkit (version 2.0)\n9.0, 8.2\n\n\nSitecore Azure Toolkit (version 1.1)\n8.2\n\n\nEXM Delivery Cloud\n10, 9.3, 9.2, 9.1, 9.0, 3.5, 3.4\n\n\nSitecore on Azure\n10, 9.3, 9.2, 9.1, 9.0, 8.2\n\n\nSolrCloud on Sitecore', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Sitecore on Azure\n10, 9.3, 9.2, 9.1, 9.0, 8.2\n\n\nSolrCloud on Sitecore\n10.1, 10, 9.3, 9.2, 9.1, 9.0\n\n\nxDB Cloud (version 2.0)\n8.2\n\n\nxDB Cloud (version 1.0)\n8.1, 8.0\n\n\nSitecore modules in the Cloud\nThe following Sitecore modules interact with Sitecore Cloud Services:', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Sitecore Experience Accelerator (SXA).\nSitecore Experience Commerce.\n\n\nXConnect (Salesforce and Sitecore Experience Platform (XP)).\nWeb Forms For Marketers (WFFM) - versions 8.2 and 8.1.\n\n\nEmail Experience Manager (EXM), by way of EXM Delivery Cloud - versions 9.1 and later.\nExperience Explorer.', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Experience Explorer.\n\n\nAzure Monitoring and Alerts\nWhat is Azure Monitoring and Alerts?\n\n\nThe Azure Monitoring and Alerts Basic module uses Azure Monitor to track whether specific resources are performing within acceptable boundaries.\nWhat would I use Azure Monitoring and alerts for?', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='A part of the Contingency planning complement, use Azure Monitoring and Alerts to allow Managed Cloud to monitor your system, to provide HADR-based abilities, and enable troubleshooting. You can customize the tiles, dashboards, and alerts that you receive when you install Sitecore Application Level', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='alerts that you receive when you install Sitecore Application Level Monitoring.', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Use the Azure Monitoring and Alerts module with High Availability Disaster Recovery (HADR).\n\n\nAzure Search and indexing\nWhat is Azure Search and indexing?', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='Azure Search and indexing\nWhat is Azure Search and indexing?\n\n\nAzure Search (now known as Azure Cognitive Search), is a search-as-a-service in the cloud that includes standard or AI enriched indexing solutions.\nWhat would I use Azure Cognitive Search and indexing for?', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='What would I use Azure Cognitive Search and indexing for?\n\n\nA part of the Search and scalability complement, use the Switch On Rebuild feature of Azure Cognitive Search and indexing to avoid Search functionality downtime during a full rebuild of the Sitecore Search index.', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='An alternative to Azure Cognitive Search for indexing is SolrCloud.\n\n\nAzure Session State\nWhat is Azure Session State?', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'}),
#  Document(page_content='When contacts browse a website, data about their interactions with Sitecore is stored in session state, (private or shared). A private session state contains contact visit information, such as pages viewed, goals converted, or campaigns triggered. A shared session state contains information that', metadata={'source': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'loc': 'https://doc.sitecore.com/xp/en/developers/100/managed-cloud/sitecore-cloud-services-overview.html', 'lastmod': '2021-11-26', 'title': 'Sitecore Cloud Services overview'})]
